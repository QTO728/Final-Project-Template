# %%
# Import necessary packages here, e.g.
import numpy as np               # for numerical operations
import matplotlib.pyplot as plt  # for plotting

# Add other packages as needed, for example:
import pandas as pd            # for data manipulation

# %% [markdown]
# # Climate Change effects on Mussel Length in Kenai Fjords National Park, Alaska
# *(Replace "Descriptive Project Title" above with the actual title of your project)*
#
# **Quyen To**
# *(Replace "Your Name" with your full name)*
#
# OCEAN 215 Final Project
# Autumn 2024

# %% [markdown]
# ## Introduction
#
# <!-- Include your motivation and any background information needed to understand your research question and data analysis. Clearly state your research question and hypothesis. -->
#
# *(Write 1–2 paragraphs below)*
# For this project, i want to look at how mussel lengths changes in relation to salinity and water temperature. I learned that climate change is a major issue, and how it affects our environment badly. Global warming, salinity level drop, increased CO2, etc... And i want to incoorporate that idea with a mussel data i came across. So, i hypothesizes that mussel length decreases with the increases in water temperature and decreases in salinity level.

# %% [markdown]
# ## Data sources:
# <!-- List each data source used in your project. For each dataset, include:
#      - Where you accessed it from
#      - Date you accessed/downloaded it
#      - Data collection process
#      - Relevant variables (including unit)
#      - Spatial and temporal coverage and resolution
#      - Description of any obstacles or challenges you faced in obtaining the dataset
#      - URL to the dataset if available -->
#
# - {Dataset 1}
#   - Downloaded from {U.S. Geological Survey (USGS)} on {11/05/2024}
#   - Data collection process: no information of mussel were collected
#   - Relevant variables included: length in mm, all mussel collected were greater the 20mm in length.
#   - Spatial coverage and resolution: mussels were collected over three intertidal sites which were Seward, Coleman, and Agnes. Two sites were in Resurrection Bay and the third site was in Aialik Bay. The mussel were collected on a nearly monthly basis from 2014-2015.
#   - Obstacles to data access: no problem, only file contains data for mussel from Gulf of Alaska
#   - Temporal coverage and resolution: The mussel were collected on a nearly monthly basis from 2014-2015.
#   - URL to dataset: {https://www.usgs.gov/data/bioenergetics-and-morphology-mussels-mytilus-trossulus-kenai-fjords-national-park}
# <br>
#
# - {Dataset 2}
#   - Downloaded from {U.S. Geological Survey (USGS)} on {11/05/2024}
#   - Data collection process: data were collected from bouys and oceangraphic transect.
#   - Relevant variables included: Salinity(psu).
#   - Spatial coverage and resolution:  Kachemak Bay, Prince William Sound, Katmai National Park and Preserve, and Kenai Fjords National Park.
#   - Obstacles to data access: There are multiple data of water temperature of different places, so i had to find the one with closes location to the mussel data.
#   - Temporal coverage and resolution: data were collected every 30 mins for 1 year (06/2014-06/2015)
#   - URL to dataset: {https://www.sciencebase.gov/catalog/item/63113045d34e36012efa10ef}
#   <br>
#
# - {Dataset 3}
#   - Downloaded from {Gulf Watch of Alaska on {11/05/2024}
#   - Data collection process: data were collected from CTD below 20m.
#   - Relevant variables included: Degree Celcius (C), tide height (m).
#   - Spatial coverage and resolution: data were collected near the Resurrection Bay in Gulf of Alaska.
#   - Obstacles to data access: There are multiple files with different time range, so i had to go through and pick the data with the matching time range to the mussel data.
#   - Temporal coverage and resolution: data were collected every 15 mins since 1970s and still going.
#   - URL to dataset: {https://gulfwatchalaska.org/monitoring/environmental-drivers/gulf-of-alaska-mooring-gak1-monitoring/}https://www.sciencebase.gov/catalog/item/63113045d34e36012efa10ef

# %% [markdown]
# ## 1. {Section 1 Title}
# *(Replace "Section 1 Title" with something meaningful, e.g., "Analyzing Seasonal Temperature Trends")*
#
# <!-- In this cell, introduction the data set(s) you are working with, specify which aspect of your research question this section addresses, and describe the figure you will produce. -->
#
# For this first graph, i used the mussel length data and the salinity level data to graph the relationship. This will help answer my question of how salinity level affect mussel length. I intend to create a twin graph with the error bar showing the high and low of mussel length throughout the year (2014-2015) and the salinity level to be graphed on top of it.

# %%
# load data file(s)
first_source = "mussel_morphologyBioenergetics_kenaiFjords_robinson_2014-2015 (2).csv"
third_source = "UAF_GAK1_2014_ctd014m_L2_v2.csv"

mussel_df = pd.read_csv(first_source, delimiter=',', delim_whitespace=False,
                       header=0, parse_dates=['CollectionDate'])
salinity_df = pd.read_csv(third_source, parse_dates=['Date_Time_[UTC]'])
# as part of commenting your code throughout this section, discuss any problems you encountered and how you solved them

# %%
# perform data cleaning steps
mussel_df = mussel_df.sort_values("CollectionDate")

# Set the time as the index in both data
mussel_df.set_index('CollectionDate', inplace=True)
salinity_df.set_index('Date_Time_[UTC]', inplace = True)

# Groups the data into max and min data.
mussel_max = mussel_df.groupby(mussel_df.index).max(numeric_only = True)
mussel_min = mussel_df.groupby(mussel_df.index).min(numeric_only =True)

# %%
# perform data analysis
mussel_df = mussel_df['Length'].resample('M').mean()
mussel_df_sel = mussel_df.loc[:'2015-03-01']
mussel_df_sel = mussel_df_sel.interpolate()

mussel_max = mussel_max['Length'].resample('M').mean()
mussel_min = mussel_min['Length'].resample('M').mean()

# Index mussel data to the wanter time range
mussel_max_sel = mussel_max.loc[:'2015-03-01']
mussel_min_sel = mussel_min.loc[:'2015-03-01']

# Gets the absolute values for the error bar.
max_diff = np.abs(mussel_df_sel - mussel_max_sel)
min_diff = np.abs(mussel_df_sel - mussel_min_sel)

# Creates 2D array for the error bar
errs = np.empty((2, len(max_diff)))
errs[0] = min_diff
errs[1] = max_diff

# Gets the monthly mean of the salinity level.
salinity_df = salinity_df['Salinity_[psu]'].resample('M').mean()
# Index the data to this time range.
salinity_df_sel = salinity_df.loc['2014-04-30':'2015-03-01']

# Some limitations are that data has to be sorted according to time, and some month has lower 
# data and some months has a lot more data, so it was hard to show all the data points on
# the graph.

# %%
# make and display the first figure
# Plots figures
fig,ax = plt.subplots(figsize=(10,5))
line1 = ax.errorbar(mussel_df_sel.index, mussel_df_sel, yerr=errs, fmt='.-', 
                    markersize=15, capsize=5, capthick=2, c='darkblue', label="Length")
ax.set_xlabel('Time (month)')
ax.set_ylabel('Length (mm)')
# Rotate the time on the x-axis
plt.xticks(rotation=45)

# Creates a twin graph
ax2 = ax.twinx()
ax2.plot(salinity_df_sel.index, salinity_df_sel, c='g', linestyle='-', 
         label="Salinity", marker='o', markersize=6)

# Adds legends
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax.legend(lines + lines2, labels + labels2, loc="lower right")
#ax.legend(loc="lower right")
ax2.set_ylabel('Salinity (psu)')
ax.grid()
ax.set_title("Mussel's Length in Kenai Fjords National Park (2014-2015)")
# Out:
# Text(0.5, 1.0, "Mussel's Length in Kenai Fjords National Park (2014-2015)")

# %% [markdown]
# <!-- Describe how this figure helps address your research question. What patterns or insights can you observe? -->
# **Figure 1 Caption:** Your caption here.
# This graph shows the salinity level decreased from 05/2014 - 10/2014 and increased from 10/2014 - 03/2015. The error bars show the range of the length, with longest and shortest length and the mean in the middle. There is kind of a trend when the length started to increased from 10/2014 - 03/2015 as salinity also increased. The mussel's length mean also highest around 02/2015 and 03/2015.

# %% [markdown]
# ## 2. {Section 2 Title}
#
# <!-- In the introduction below, specify the data set(s) you are working with in this section, which aspect of your research question this section addresses, and the figure you will produce -->
#
# Short introduction to this section here.
# The data i use for this second graph is the mussel length data and the water temperature data from the 3rd source. The figure i will produce is a scatter plot with a color bar, the plot will shows the length in that month with the fitting color represents the water temperature in that month.

# %%
# if a new dataset, load data and perform data cleaning steps
# otherwise, continue to data analysis and figure creation
# Data imports
sec_source = "Intertidal_Temperature_KEFJ_2014-2015.csv"
# Reads in the file and set the time to datetime object.
water_df = pd.read_csv(sec_source, delimiter=',', delim_whitespace=False,
                       header=0, parse_dates=['date'])

# Set time as index
water_df.set_index('date', inplace = True)

# %%
# perform data analysis
# Resample the data to monthly mean
water_temp = water_df['temperature'].resample('M').mean()

# Index the data to the desired time range
water_temp_sel = water_temp.loc['2014-06-01':'2015-03-01']
mussel_df_sel2 = mussel_df.loc['2014-06-01':'2015-03-01']
# Interpolates the missing data from mussel data.
mussel_df_sel2 = mussel_df_sel2.interpolate()

# A limitation i found were that the time scale of the water temperature data is really short, 
# only 9 months, which is hard to plot with the mussel data. Also i don't know about 
# depth that the mussel data were collected so the data accuracy is not good.

# %%
# make and display figure
fig1,ax1 = plt.subplots(figsize=(10,5))
sc = ax1.scatter(mussel_df_sel2.index, mussel_df_sel2, c=water_temp_sel)
# makes a color bar
cbar = fig1.colorbar(sc)
cbar.set_label("Temperature (C)", fontsize=10)
ax1.set_xlabel('Time (months)')
ax1.set_ylabel('Length (mm)')
ax1.set_title("Mussel's Length vs. water temperature")
# rotates the time on x-axis
plt.xticks(rotation=45)
ax1.grid()

# %% [markdown]
# <!-- Describe how this figure helps address your research question. What patterns or insights can you observe? -->
# **Figure 2 Caption:**
# This graph shows the temperature and mussel length from 07/2014 - 03/2015. There is a trend of temperature decreasing as the graph shifts into winter season from summer. There is a drop in mussel length on October 2014. The mussel length increases with the temperature decreases. The highest mussel length is 37 mm on 02/2015.

# %% [markdown]
# ## Discussion
# **Interpretation of Results:**  *(Write ~1 paragraph below)*
# <!-- Summarize what you learned from each data analysis section/figure. Discuss key insights and conclusions regarding your research question. Do your results support or contradict your hypothesis? -->
# So, for the first plot, i wanted to see how mussel length changes correlate with salinity level. There was a little bit of trend of mussel length increasing from 10/2014 - 03/2015 when the salinity level was also increasing. But there is also high concentration of long mussel than the mean length on 10/2014 when the salinity level was very low as 27.5 psu. So the graph doesn't support the first hypothesis and i assume that there is other factor that has bigger effects on the mussel length than salinity level, or that there is a range of salinity level that the mussel grows the best. For the second graph, it shows that the mussel lengths increases as the temperature decreases which support the second hypothesis that the mussel length is lot longer during colder temperature. However, there is a drop in mussel length when the water temperature were still decreasing on 10/2014. So i assume that there might be other factors that contributed to this drop in mussel length. In conclusion, the mussel does grow longer during lower temeprature but no clear pattern on the relationship between mussel length and salinity which needs more data to check the first hypothesis.
#
# **Limitations and Future Work:**  *(Write ~1 paragraph below)*
# <!-- Identify limitations in your analysis. Discuss any factors that may have impacted the validity or reliability of your results (e.g., data quality, sample size, assumptions). -->
# <!-- What next steps could you or another researcher take to continue investigating this research question? Suggest ideas for further research, data collection, or alternative methodologies that could enhance understanding of the topic. -->
# The data i was working with all have low temporal scale of only 1 year span, so i can't really determine if these factors are affected by climate change. Also the depth of where data colelcted are not match up to each other, so there is inaccuracy in plots. For future research, i would look at the atmospheric temperature to match them with the salinity and water temperature to see the relationship between climate change and these factors. Also, i would use a bigger time scale to really see the effects of climate change on the mussel, beside the length of the mussel, i would also use the mass of the mussel to dive in more on how climate change affects mussel growth.

# %% [markdown]
# ## References
#
# *Cite all papers, websites, or other resources you referenced in your project. Use a consistent citation style (e.g., APA, MLA, Chicago).*
#
# 1. **Author(s).** (Year). *Title of the work*. Publisher. URL (if applicable)
#
# 3. **Website Name.** (Date accessed). *Title of the webpage*. URL
#
# Robinson, B. H., Kloecker, K., & Esler, D. N. (2022). Bioenergetics and morphology of mussels (Mytilus Trossulus) in Kenai Fjords National Park. Bioenergetics and Morphology of Mussels (Mytilus trossulus) in Kenai Fjords National Park | U.S. Geological Survey. https://www.usgs.gov/data/bioenergetics-and-morphology-mussels-mytilus-trossulus-kenai-fjords-national-park
#
# Danielson, S., & Weingartner, T. (2012). Gulf of Alaska Mooring (GAK1). Gulf Watch Alaska. https://gulfwatchalaska.org/monitoring/environmental-drivers/gulf-of-alaska-mooring-gak1-monitoring/
#
# U.S. Geological Survey - Alaska Science Center, National Park Service - Southwest Alaska Inventory and Monitoring Network, and University of Alaska Fairbanks - College of Fisheries and Ocean Sciences, 2016, Intertidal temperature data from Kachemak Bay, Prince William Sound, Katmai National Park and Preserve, and Kenai Fjords National Park (ver 5.0, October 2024): U.S. Geological Survey data release,
# https://www.sciencebase.gov/catalog/item/63113045d34e36012efa10ef
#
# *Continue listing additional references as needed.*
